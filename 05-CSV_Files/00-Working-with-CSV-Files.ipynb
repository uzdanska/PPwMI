# %% [markdown]
# # Working with CSV Files
#
# Let's discuss how to work with CSV files in Python. A file with the CSV file extension is a Comma Separated Values file. All CSV files are plain text, contain alphanumeric characters, and structure the data contained within them in a tabular form. Don't confuse Excel Files with csv files, while csv files are formatted very similarly to excel files, they don't have data types for their values, they are all strings with no font or color. They also don't have worksheets the way an excel file does. Python does have several libraries for working with Excel files, you can check them out [here](http://www.python-excel.org/) and [here](https://www.xlwings.org/).
#
# Files in the CSV format are generally used to exchange data, usually when there's a large amount, between different applications. Database programs, analytical software, and other applications that store massive amounts of information (like contacts and customer data), will usually support the CSV format.
#
# Let's explore how we can open a csv file with Python's built-in csv library.

# %% [markdown]
# ____
# ** Notebook Location. **
#
# Run **pwd** inside a notebook cell to find out where your notebook is located

# %%
pwd
# Out:
# 'c:\\Users\\urszu\\OneDrive\\Dokumenty\\Podstawy programowania w metodach ilościowych\\sgh_python\\05-CSV_Files'

# %% [markdown]
# ____
# ## Reading CSV Files

# %%
import csv

# %% [markdown]
# When passing in the file path, make sure to include the extension if it has one, you should be able to Tab Autocomplete the file name. If you can't Tab autocomplete, that is a good indicator your file is not in the same location as your notebook. You can always type in the entire file path (it will look similar in formatting to the output of **pwd**.

# %%
data = open('example.csv')

# %%
data
# Out:
# <_io.TextIOWrapper name='example.csv' mode='r' encoding='cp1250'>

# %% [markdown]
# ### Encoding
#
# Often csv files may contain characters that you can't interpret with standard python, this could be something like an **@** symbol, or even foreign characters. Let's view an example of this sort of error ([its pretty common, so its important to go over](https://stackoverflow.com/questions/9233027/unicodedecodeerror-charmap-codec-cant-decode-byte-x-in-position-y-character)).

# %%
csv_data = csv.reader(data)

# %% [markdown]
# Cast to a list will give an error, note the **can't decode** line in the error, this is a giveaway that we have an encoding problem!

# %%
data_lines = list(csv_data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\urszu\OneDrive\Dokumenty\Podstawy programowania w metodach ilościowych\sgh_python\05-CSV_Files\00-Working-with-CSV-Files.ipynb Cell 12 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/urszu/OneDrive/Dokumenty/Podstawy%20programowania%20w%20metodach%20ilo%C5%9Bciowych/sgh_python/05-CSV_Files/00-Working-with-CSV-Files.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> data_lines = list(csv_data)
#
# File c:\Users\urszu\AppData\Local\Programs\Python\Python310\lib\encodings\cp1250.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1916: character maps to <undefined>

# %% [markdown]
# Let's not try reading it with a "utf-8" encoding.

# %%
data = open('example.csv',encoding="utf-8")
csv_data = csv.reader(data)
data_lines = list(csv_data)

# %%
# Looks like it worked!
data_lines[:3]
# Out:
# [['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city'],
#  ['1',
#   'Joseph',
#   'Zaniolini',
#   'jzaniolini0@simplemachines.org',
#   'Male',
#   '163.168.68.132',
#   'Pedro Leopoldo'],
#  ['2',
#   'Freida',
#   'Drillingcourt',
#   'fdrillingcourt1@umich.edu',
#   'Female',
#   '97.212.102.79',
#   'Buri']]

# %% [markdown]
# Note the first item in the list is the header line, this contains the information about what each column represents. Let's format our printing just a bit:

# %%
for line in data_lines[:5]:
    print(line)
# Out:
# ['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city']
# ['1', 'Joseph', 'Zaniolini', 'jzaniolini0@simplemachines.org', 'Male', '163.168.68.132', 'Pedro Leopoldo']
# ['2', 'Freida', 'Drillingcourt', 'fdrillingcourt1@umich.edu', 'Female', '97.212.102.79', 'Buri']
# ['3', 'Nanni', 'Herity', 'nherity2@statcounter.com', 'Female', '145.151.178.98', 'Claver']
# ['4', 'Orazio', 'Frayling', 'ofrayling3@economist.com', 'Male', '25.199.143.143', 'Kungur']

# %% [markdown]
# Let's imagine we wanted a list of  all the emails. For demonstration, since there are 1000 items plus the header, we will only do a few rows.

# %%
len(data_lines)
# Out:
# 1001

# %%
all_emails = []
for line in data_lines[1:15]:
    all_emails.append(line[3])

# %%
print(all_emails)
# Out:
# ['jzaniolini0@simplemachines.org', 'fdrillingcourt1@umich.edu', 'nherity2@statcounter.com', 'ofrayling3@economist.com', 'jmurrison4@cbslocal.com', 'lgamet5@list-manage.com', 'dhowatt6@amazon.com', 'kherion7@amazon.com', 'chedworth8@china.com.cn', 'hgasquoine9@google.ru', 'ftarra@shareasale.com', 'abathb@umn.edu', 'lchastangc@goo.gl', 'cceried@yale.edu']

# %% [markdown]
# What if we wanted a list of full names?

# %%
#todo10

full_names = []
for line in data_lines[1:]:
    full_names.append(line[1] + " " + line[2])

# %%
full_names
# Out:
# ['Joseph Zaniolini',
#  'Freida Drillingcourt',
#  'Nanni Herity',
#  'Orazio Frayling',
#  'Julianne Murrison',
#  'Lucy Gamet',
#  'Dyana Howatt',
#  'Kassey Herion',
#  'Chrissy Hedworth',
#  'Hyatt Gasquoine',
#  'Felicdad Tarr',
#  'Andrew Bath',
#  'Lucais Chastang',
#  'Car Cerie',
#  'Alvera Jepp',
#  'Prescott Caldeiro',
#  'Nariko Clunie',
#  'Kalvin Rois',
#  'Isa Boycott',
#  'Benedetta Glanert',
#  'Poul Caroli',
#  'Virgie Dran',
#  'Gillie Roantree',
#  'Tabor Dawidowitsch',
#  'Sarina Choulerton',
#  'Elbert Seawell',
#  'Danita Aldrin',
#  'Jone Dank',
#  'Merralee Lampel',
#  'Charyl Halstead',
#  'Giuseppe Karolowski',
#  'Sutherlan Mundee',
#  'Alexander Oldershaw',
#  'Blayne Mattusevich',
#  'Alfredo Bohlens',
#  'Harman Braidwood',
#  'Haslett Sudron',
#  'Jeanelle VanBrugh',
#  'Hetty Lightollers',
#  'Elmira Goodhand',
#  'Granger Lewerenz',
#  'Tobie Lewson',
#  'Knox Sainteau',
#  'Eliot Vedekhov',
#  'Honey Crenshaw',
#  'Karmen Soppitt',
#  'Fairleigh Sivess',
#  'Angelina Stranio',
#  'Lilla Erni',
#  'Penn Batson',
#  'Salvidor Cawthry',
#  'Ker Kellock',
#  'Lorne Smouten',
#  'Elijah Sore',
#  'Paxton Chsteney',
#  'Ernie Eddies',
#  'Deb Endicott',
#  'Morna Masse',
#  'Gregorius Drains',
#  'Raynard Teaz',
#  'Harrietta Northey',
#  'Cariotta Le Breton De La Vieuville',
#  'Lisetta Allbones',
#  'Danielle Jeduch',
#  'Ingra Andriolli',
#  'Ferdinand Cruickshanks',
#  'Salomi Pinnock',
#  'Lurlene Snazel',
#  'Penni Sells',
#  'Stormie Dougal',
#  'Baily Hallwell',
#  'Kristofor Recke',
#  'Cherey Dorricott',
#  'Phillip Bartolijn',
#  'Karil Hefford',
#  'Loise Issacof',
#  'Rickie Laybourn',
#  'Orella Giacomuzzo',
#  "Calli D'orsay",
#  'Harli Fakeley',
#  'Edvard Morilla',
#  'Almira Eastmead',
#  'Kort Blooman',
#  'Sigmund Sessions',
#  'Winna Dodshon',
#  'Norton Raiston',
#  'Moss Doche',
#  'Jeanna Mazey',
#  'Kerrin Rojahn',
#  'Luca Frazier',
#  'Faina Jarville',
#  'Skelly Cragg',
#  'Mike Kennewell',
#  'Trever Bradie',
#  'Ferdinande Drought',
#  'Brenda Guiel',
#  'Matthiew Vanyukov',
#  'Rosalie Stribbling',
#  'Flor Giuron',
#  'Ax Bristowe',
#  'Guglielma Magenny',
#  'Kyla Crosse',
#  'Brittan Bubb',
#  'Corri Rubinowicz',
#  'Korney Prestidge',
#  'Paddie Dary',
#  'Ase Fibbens',
#  'Susi Pawsey',
#  'Jo Walak',
#  'Ardelia Vasilyonok',
#  'Alis Stammer',
#  'Al Gravatt',
#  'Osborne Fendlow',
#  'Brook Purvey',
#  'Mag Feechan',
#  'Luigi Reaveley',
#  'Tymon Castro',
#  'Minnaminnie MacNair',
#  'Hugues MacFarlane',
#  'Fianna Moizer',
#  'Morton Derby',
#  'Carita Tomet',
#  'Beulah MacGowan',
#  'Etta Riccardelli',
#  'Udall Chevers',
#  'Javier Spitell',
#  'Munmro Snelling',
#  'Carina Moxon',
#  'Crissy Murdie',
#  'Karrah Danshin',
#  'Idalina Hartup',
#  'Denice Cargon',
#  'Courtnay Tosh',
#  'Harp Szymoni',
#  'Franklin Tregian',
#  'Celestyna Jacquemy',
#  'Silva Pittham',
#  'Kendra Arnow',
#  'Cordie Monier',
#  'Tabbitha Padbery',
#  'Haydon Sheran',
#  'Halli Clempton',
#  'Gwenette Helling',
#  'Ermina Carff',
#  'Tedd Howler',
#  'Wren Janc',
#  'Anatola Upsale',
#  'Ken Muirhead',
#  'Jerri Bohje',
#  'Julie Kopacek',
#  'Ingelbert Loveday',
#  'Elaina Yanez',
#  'Uri Aven',
#  'Ally Clausen-Thue',
#  'Ki Clew',
#  'Francesca Cottham',
#  'Aida Mundy',
#  'Aloin Dimelow',
#  'Edgar Raithbie',
#  'Thorvald Gunstone',
#  'Temp Karet',
#  'Corinna Naismith',
#  'Cinnamon Birchenhead',
#  'Tilda Couser',
#  'Tildi Kimbell',
#  'Jeno Marran',
#  'Mariska Noble',
#  'Rozelle Northrop',
#  'Petey Thompkins',
#  'Alvie Pyffe',
#  'Kev MacKniely',
#  'Matelda Wycliffe',
#  'Leoline Flawith',
#  'Malachi Fodden',
#  'Pierrette Abramow',
#  'Lynn Sames',
#  'Krisha Jinkins',
#  'Cassie Bramich',
#  'Cynthia MacTurlough',
#  'Care Lademann',
#  'Torrey Nye',
#  'Conni Higgan',
#  'Franky Casarini',
#  'Alva Feechan',
#  'Gaby Synder',
#  'Andy Varley',
#  'Ronda Heavens',
#  'Elwin Hounsham',
#  'Faythe Pither',
#  'Carling Arkell',
#  'Kurtis Saddington',
#  'Dennison Woolatt',
#  'Leda Luchetti',
#  'Britt Vile',
#  'Gertrude Iddison',
#  'Kathi Kerne',
#  'Caitlin Zannutti',
#  'Sanson Ramelot',
#  'Krista Cowoppe',
#  'Laurella Hotchkin',
#  'Juliane Koba',
#  'Tobe Hamlyn',
#  'Neddie Kwietek',
#  'Dav Donet',
#  'Amelia Peggs',
#  'Robby Heijnen',
#  'Loria Serrier',
#  'Nan Witch',
#  'Mauricio Curr',
#  'Micheal Whiteson',
#  'Denys Esmonde',
#  'Sibilla Stachini',
#  'Enrique Roman',
#  'Edyth Macartney',
#  'Lisetta Bigglestone',
#  'Colin Younghusband',
#  'Britni Cottham',
#  'Matias Tudor',
#  "Carina O' Ronan",
#  'Albrecht Airds',
#  'Randy Sazio',
#  'Timmie Scotti',
#  'Gerik Milligan',
#  'Ardys Diben',
#  'Ellery Bruni',
#  'Clarence Blenkiron',
#  'Jackie Jiruch',
#  'Melisent Northwood',
#  'Jeffy Dalliston',
#  'Joanne Lyburn',
#  'Yulma Castagneri',
#  'Marielle Chrystal',
#  'Haskell Klimshuk',
#  'Cob Mardall',
#  'Shep Voyce',
#  'Geno Crayden',
#  'Friedrich Giblin',
#  'Desmund Belamy',
#  'Rafe Wratten',
#  'Flo Sorrie',
#  'Elvina Dulwitch',
#  'Dell Rafe',
#  'Diena Jahan',
#  'Gino Skuce',
#  'Heath Eastmond',
#  'Meg McKirdy',
#  'Hastie Hadley',
#  'Westleigh Willetts',
#  'Lee Bagnal',
#  'Hildegaard Fairey',
#  'Easter Hamshere',
#  'Elton Tows',
#  'Verile Gunning',
#  'Brandtr Margeram',
#  'Ozzie Zecchii',
#  'Daniella Jindra',
#  'Shoshanna Stollsteimer',
#  'Benton Jahnig',
#  'Noel Selliman',
#  'Clarke Tidcomb',
#  'Brigitta Haquin',
#  'Claribel Dosedale',
#  'Gallard Wanden',
#  'Marleah Shevlan',
#  'Saundra Butterfint',
#  'Opalina Bleier',
#  'Shaughn Antoniades',
#  'Kathleen Treswell',
#  'Mufinella Santo',
#  'Marlin Wheeliker',
#  'Aldon Wozencraft',
#  'Beaufort Petrello',
#  "Marmaduke O'Malley",
#  'Kathryn MacManus',
#  'Eve Clother',
#  'Obediah Janus',
#  'Emmy Negri',
#  'Mill Wesson',
#  'Tiertza Bullivent',
#  'Berne Scrivener',
#  'Rozella Shirlaw',
#  'Emmit Cruttenden',
#  'Iseabal Terron',
#  'Michele Garritley',
#  'Theodoric Deave',
#  'Sibilla Alesi',
#  'Erick Austick',
#  'Hercules Dowall',
#  'Ellene Glisane',
#  'Bren Marchenko',
#  'Oralee Letchmore',
#  'Hamilton Horsley',
#  'Fanya Gartan',
#  'Godfrey Cattrell',
#  'Vania Sinnott',
#  'Osmond Reichert',
#  'Colline Meadowcroft',
#  'Marybelle Neathway',
#  'Laetitia Sidry',
#  'Gasparo Burr',
#  'Darin Gitting',
#  'Lotti Linnock',
#  'Lilly Annear',
#  'Freda Winslade',
#  'Stavros McGeady',
#  'Marje Fordyce',
#  'Willard Widdall',
#  'Meridel Ledford',
#  'Catrina Whiskerd',
#  'Chucho Lewton',
#  'Rakel Fitzsymons',
#  'Caye Canton',
#  'Clari Thowless',
#  'Thia Vasyanin',
#  'Laird Insoll',
#  'Jany Holbie',
#  'Adlai Harm',
#  'Doy Riccetti',
#  'Elvera Bowdrey',
#  'Kalli Critcher',
#  'Carny Growden',
#  'Brook Caff',
#  'Frankie Warburton',
#  'Mahmud Ferby',
#  'Tamas MacPaik',
#  'Tulley Twiggs',
#  'Tony Venny',
#  'Dwain Verrick',
#  'Adaline Gligoraci',
#  'Bronny Innman',
#  'Sydel Sherland',
#  'Nelie Barnard',
#  'Keary Jamary',
#  'Elwood Mingardi',
#  'Ellwood Meegan',
#  'Berry Gribbins',
#  'Alys Gerge',
#  'Mufinella Harcus',
#  'Nap Messiter',
#  'Hy Drewry',
#  'Maressa Andras',
#  'Gayla Hebbes',
#  'Stephenie Hurt',
#  'Sergei Blumson',
#  'Berke Fashion',
#  'Gal Bestiman',
#  'Rosalind Macieja',
#  'Roderick Hush',
#  'Libbie Gabbotts',
#  'Pippy Thickins',
#  'Manny Denny',
#  'Florie Cuthbertson',
#  'Simone McMychem',
#  'Lyn Chivers',
#  'Devlin Woodhouse',
#  'Dulcie Dower',
#  'Aaron Baker',
#  "Benedikta O'Crevan",
#  'Saudra McGrill',
#  'Meggy Birbeck',
#  'Link McGuinness',
#  'Bertha Vondrach',
#  'Nert Finby',
#  'Fairleigh Brunt',
#  'Genni Cabrales',
#  'Rosella Kenney',
#  'Rodrique Elderbrant',
#  'Moise Kaspar',
#  'Betteann Mayall',
#  'Colleen Ikringill',
#  'Eleni Yakushkev',
#  'Carolus Sainz',
#  'Towney Slimme',
#  'Fifine Petto',
#  'Ernesto Schlag',
#  'Rorke Coot',
#  'Courtney Terry',
#  'Delinda Jirka',
#  'Kipp Grigoletti',
#  'Bailey Colbeck',
#  'Wilburt Gopsall',
#  'Venita Bainbridge',
#  'Lelia Collingworth',
#  'Kate Cusworth',
#  'Lenore Domenicone',
#  'Fidole Drillingcourt',
#  'Kariotta Diloway',
#  'Camila Beveredge',
#  'Myrwyn Marcham',
#  'Stephi Miskimmon',
#  'Averill Sciusscietto',
#  'Caleb Satch',
#  'Curt Rowlands',
#  'Randie McKennan',
#  'Jacenta Follacaro',
#  'Danie Baddam',
#  'Lucius Rankmore',
#  'Teddie Iglesia',
#  'Chaunce Boyse',
#  'Gerrie Cronkshaw',
#  'Alexandra Ortsmann',
#  'Jillian Larrett',
#  'Jens Shewan',
#  'Lloyd Staunton',
#  'York Tockell',
#  'Gardiner Watterson',
#  'Ernesto Doughartie',
#  'Lanni Nice',
#  'Jeannie Slane',
#  'Obediah Akers',
#  'Minnnie Tomkinson',
#  'Salomone Arsey',
#  'Vernen Linnock',
#  'Ignatius Fleeman',
#  'Orton Motte',
#  'Ferdinande Vasenkov',
#  'Sayer Derks',
#  'Joycelin MacCallion',
#  'Marice Armin',
#  'Misti Feaveer',
#  'Myles Gordge',
#  'Anissa Trowler',
#  'Willi Human',
#  'Branden Muglestone',
#  'Saxe Hegdonne',
#  'Therine Kelsell',
#  'Pietrek Athersmith',
#  'Humberto Bengtsen',
#  'Lilli De Bruijne',
#  'Lizette MacCard',
#  'Edwina Colleer',
#  'Channa Kuhnhardt',
#  'Melva Walbrook',
#  'Carlie Belone',
#  'Christiano Bru',
#  'Mary Reven',
#  'Sib Chavey',
#  'Aurlie Mossop',
#  'Antonina Evershed',
#  'Ajay Orth',
#  'Ollie Codlin',
#  'Boycey Chanter',
#  'Flory Coch',
#  'Donavon Lackeye',
#  'Vivyan Staley',
#  'Robinetta Perse',
#  'Lisbeth Huetson',
#  'Sidonnie Ianelli',
#  'Yetty Creebo',
#  'Reuven Surgeon',
#  'Tommi Gooda',
#  'Mac Edelston',
#  'Lavinia Englefield',
#  'Randall Balser',
#  'Griffy Anand',
#  'Penni Sharpley',
#  'Torr Briggdale',
#  'Sauveur Povele',
#  'Bea Vallerine',
#  'Holt Strippling',
#  'Dell Blewitt',
#  'Anett Bertrand',
#  'Alford Rowbottom',
#  'Merralee Fidelli',
#  'Fidole Hove',
#  'Eldredge Corbally',
#  'Carlin Mc Combe',
#  'Penelope Rehme',
#  'Susann Sciusscietto',
#  'Zorah MacMenemy',
#  'Andrew Label',
#  'Claudina Scogin',
#  'Skippie Obern',
#  'Pandora Gadie',
#  'Evy Hoyer',
#  'Dinny Avo',
#  'Elyn Giraldo',
#  'Brewer Lowdwell',
#  'Fanya Backshall',
#  'Brockie Rioch',
#  'Wyatt Ribbens',
#  'Annette Griffin',
#  'Dorothy Barnard',
#  'Lexis Drillingcourt',
#  'Rhodia Bainton',
#  'Eli Hammerson',
#  'Danella Hancox',
#  'Jody Hounsom',
#  'Bradan Crain',
#  'Asher Roycroft',
#  'Gaylor Southcott',
#  'Bondy Josefer',
#  'Darelle Parkey',
#  "Nikos O'Lyhane",
#  'Glenn Gellion',
#  'Laryssa Foucher',
#  'Lewes Bonome',
#  'Taber Critchley',
#  'Julie Tomaselli',
#  'Jacqueline Bourgourd',
#  'Ambur Holdey',
#  'Sabine Lyosik',
#  'Gladys Bandt',
#  'Paten Vasyukhichev',
#  'Hunter Creggan',
#  'Robert Dodridge',
#  'Cash Dunklee',
#  'Thurstan Broomhall',
#  'Garald Hackin',
#  'Novelia Dureden',
#  'Cathlene Elgood',
#  'Tyler Latore',
#  'Filbert Bulloch',
#  'Katherine Dand',
#  'Ferdy Richold',
#  'Warner Almond',
#  'Lorrie Elcomb',
#  'Granville Garnsworth',
#  'Tye Labon',
#  'Raoul Comelli',
#  'Candida Jikylls',
#  'Noni Whoston',
#  'Laurent Althorp',
#  'Dwight Messenger',
#  'Vinny Riddell',
#  'Wendie Shaplin',
#  'Shurwood Sisneros',
#  'Brenda Rogliero',
#  'Alyce Scotter',
#  'Clare Swainson',
#  'Lurleen Kerswill',
#  'Woodman Hadny',
#  'Gerianne Tryhorn',
#  'Avigdor Stadden',
#  'Dennet Plessing',
#  'Tabbie Farge',
#  'Cristionna MacBain',
#  'Leonie Brocket',
#  'Lief Bielby',
#  'Kellen Chew',
#  'Chico Lismore',
#  'Dan Baldetti',
#  'Stormi Schimke',
#  'Letta Meneyer',
#  'Adah Larder',
#  'Gerri McQuade',
#  'Parke Charteris',
#  'Chico Hardwick',
#  'Peder Coakley',
#  'Chelsea Verriour',
#  'Carina Yurmanovev',
#  'Brittne Hawkshaw',
#  'Candy Dreakin',
#  'Raynard Sperring',
#  'Angel covino',
#  'Judy Yesenev',
#  'Thibaut Demsey',
#  'Esmaria Tidman',
#  'Michaela Yandle',
#  'Lincoln Conboy',
#  'Bartram Agass',
#  'Guendolen Iacovino',
#  'Glenda Shenley',
#  'Dedra Kempe',
#  'Paten Selborne',
#  'Mill Tanguy',
#  'Jonathan Abbess',
#  'Lester Dyton',
#  'Hynda Dahlback',
#  'Willi Crannach',
#  'Hinda Reinisch',
#  'Margareta Strainge',
#  'Modestine Rayer',
#  'Maurizia Costen',
#  'Crosby Rosenfelt',
#  'Willie von Grollmann',
#  'Laurice Pople',
#  'Colan Cluet',
#  'Bertina Buist',
#  'Alli Creedland',
#  'Engelbert Fahy',
#  'Arch Wightman',
#  'Allyn Towl',
#  'Valenka Thirwell',
#  'Kelsi Roaf',
#  'Elspeth Kleinzweig',
#  'Roderick Burgis',
#  'Keven Grinham',
#  'Jere Ganley',
#  'Larry Sircombe',
#  "Jacques O'Nion",
#  'Herbert Sugg',
#  'Nettle Sinncock',
#  'Ogdan Paffot',
#  'Emile Rosellini',
#  'Lenee Howsin',
#  'Nonie Slaymaker',
#  'Wilhelmina Muzzini',
#  'Lesley Gerok',
#  'Aubrey McIlhagga',
#  'Cassey Juanes',
#  'Leigh Bernaert',
#  'Clarita Nast',
#  'Darin Grigoire',
#  'Noemi Tuttiett',
#  'Garrik Pauleau',
#  'Carlos McComiskey',
#  'Yves Heynel',
#  'Patric Herculeson',
#  'Cam Alesbrook',
#  'Nydia Edmenson',
#  'Norina Greening',
#  'Alexandros Prettyman',
#  'Neddie Clothier',
#  'Rudolfo Silly',
#  'Kerrie Casemore',
#  'Wylie De Fries',
#  'Lea Errington',
#  'Woodrow Brechin',
#  'Stafani Boggish',
#  'Jakob Varns',
#  'Norma Calley',
#  'Victoir Yurenev',
#  'Cassey Rockhall',
#  'Nilson Kimberley',
#  'Gwendolin Joselson',
#  'Reggie Bushaway',
#  'Giorgia Dundredge',
#  'Pietra McAleese',
#  'Ellynn Peterken',
#  'Umberto Schermick',
#  'Mildrid Osban',
#  'Emera Digges',
#  'Krissie Nore',
#  'Jeannine Phlippsen',
#  'Wolf Klasen',
#  'Allistir Rollingson',
#  'Suzann Hugli',
#  'Nick Lesek',
#  'Adams Denisevich',
#  'Bird Meritt',
#  'Erastus Constanza',
#  'Dinah Jandourek',
#  'Edmund Dales',
#  "Justin O'Donovan",
#  'Aeriela Thumnel',
#  'Abbie Allett',
#  'Ede Margrem',
#  'Danette Darcy',
#  'Betsey Cracknell',
#  'Ciro Caldicot',
#  'Devlen Roast',
#  'Brandy Conichie',
#  'Kimmi Kay',
#  'Kincaid Bitcheno',
#  'Lolita Castelletti',
#  'Murray MacDermott',
#  'Christie Haggath',
#  'Cassey Swidenbank',
#  'Rozanna Sambiedge',
#  'Alex Ayce',
#  'Salvador Daunter',
#  'Nobie Winks',
#  'Carling Von Brook',
#  'Lazaro Buckby',
#  'Berta Bleackly',
#  'Amalee Collocott',
#  'Penrod Tures',
#  'Isa Broxton',
#  'Bonny Folbige',
#  'Nerte Dayly',
#  'Linet Shiliton',
#  'Misti Lambell',
#  'Gwendolin McCart',
#  'Alisander Speenden',
#  'Jaquith Satterthwaite',
#  'Lucie Hadcock',
#  'Phedra Pampling',
#  'Kenton Toal',
#  'Bess Meryett',
#  'Harman Cowburn',
#  'Bobbye Rawls',
#  'Gasparo Ecclesall',
#  'Deana Glasscoe',
#  'Rani Colerick',
#  'Federico Rudinger',
#  'Cyrille Durram',
#  'Gunar Belleny',
#  'Arabel Denzilow',
#  'Curt Carville',
#  'Marvin Garshore',
#  'Jonathan Headingham',
#  'Jerrilee Saxton',
#  'Viva Robberts',
#  'Freeland Stockow',
#  'Fancy Hengoed',
#  'Dionysus Gresser',
#  'Hebert Madden',
#  'Humbert Luigi',
#  'Elladine Corbally',
#  'Trumann McFarlan',
#  'Dan Sawbridge',
#  'Clerkclaude Timoney',
#  'Marietta Dench',
#  'Patty Millimoe',
#  'Jeth Pettiward',
#  'Marlo Hendrix',
#  'Marnie Hans',
#  'Bunni DeSousa',
#  'Frans Kuhl',
#  'Cosetta Edgecombe',
#  'Crissy Pinckard',
#  'Ailene Billison',
#  'Johna Ellacott',
#  'Candide Shepstone',
#  'Bibi De Banke',
#  'Delores Haug',
#  'Kendricks Duigenan',
#  'Bernie Rattenberie',
#  'Abbe Trevarthen',
#  'Jae Matyushonok',
#  'Babs Dixcey',
#  'Betta Poxon',
#  'Mame Byatt',
#  'Jennilee Strasse',
#  'Sutton Jelk',
#  'Vannie Landrick',
#  'Phyllida Kryszka',
#  'Burt Saffill',
#  'Nelson Crudginton',
#  'Thomasin Robilart',
#  'Lari Tomovic',
#  'Rica Stable',
#  'Colver Munnis',
#  'Jerald Beesley',
#  'Reyna Cawtheray',
#  'Buiron Vlasenko',
#  'Jennine Chartman',
#  'Dallis Aldus',
#  'Carlotta McIlvaney',
#  'Tanya Raye',
#  'Idelle Jupp',
#  'Andeee Stocking',
#  'Ivie Jewise',
#  'Prentiss Lackington',
#  'Nikki Hagerty',
#  'Dannie Gowling',
#  'Francene Burnes',
#  'Troy Fawley',
#  'Randi Surr',
#  'Skipper Naisbit',
#  'Prince Halso',
#  'Dov Apthorpe',
#  'Tilda Milner',
#  'Siegfried Stewartson',
#  'Ulick Keddie',
#  'Portie Fydoe',
#  'Matty Souness',
#  'Mei Hamel',
#  'Kenton Kegg',
#  'Tabbie Wyatt',
#  'Woody Rooms',
#  'Erina Bocock',
#  'Bronnie Lutz',
#  'Alix Dohmer',
#  'Eberto Rumin',
#  'Ambrosio Burley',
#  'Skippy Odell',
#  'Killian Tillyer',
#  'Walsh Doni',
#  'Roseline Dotterill',
#  'Ariel MacMarcuis',
#  'Sherri Runacres',
#  'Belita Gorringe',
#  'Britt Kitteman',
#  'Adaline Mahony',
#  'Simeon Diloway',
#  'Nealon Dysert',
#  'Eduardo Hartman',
#  'Merline Augustine',
#  'Samara Spall',
#  'Irita Sherratt',
#  'Devonna McCaighey',
#  'Ripley McGowran',
#  'Dom Hailwood',
#  'Don Sacco',
#  'Tammy Lidierth',
#  'Quill Dewey',
#  'Jannelle Chuck',
#  'Tomasine Dennick',
#  'Mayne Brusle',
#  'Cart Escot',
#  'Emerson Southgate',
#  'Gino Delepine',
#  'Perrine Beranek',
#  'Alfonso Jados',
#  'Hali Dragonette',
#  'Bebe Mellhuish',
#  'Constantia Tomaskunas',
#  'Ashley Wollard',
#  'Aime Bruckman',
#  'Temp McMearty',
#  'Belita Kynge',
#  'Irma Gillford',
#  'Mariejeanne Mound',
#  'Shannah Daudray',
#  'Wolfy Degli Antoni',
#  'Kev Bagniuk',
#  'Tobi Doyland',
#  'Daniela Crosskell',
#  'Hayden Quade',
#  'Jodee Kitteman',
#  'Corina Lockart',
#  'Delcina MacAnelley',
#  'Yuma Tattershall',
#  'Jonathon Ipplett',
#  'Aura MacMychem',
#  'Pierre Wortman',
#  'Lowe Scini',
#  'Giustina Huckabe',
#  'Nannie Harrismith',
#  'Denny Bowry',
#  'Carney Maunders',
#  'Fonsie de Marco',
#  'Zelig Sparrowhawk',
#  'Irvine Mill',
#  'Gracie Dorsett',
#  'Pen Lundy',
#  'Arni Ducarel',
#  'Carrie Goding',
#  'Sonya Clifft',
#  'Chilton Josland',
#  'Melly Furphy',
#  'Nial Garcia',
#  'Nerta Patrick',
#  'Kissee Busby',
#  'Ellene Rosenstein',
#  'Jessamine St. Paul',
#  'Constantino Truin',
#  'Anitra Kopf',
#  'Sigismund Barnish',
#  'Giustina Dumblton',
#  'Amye Siely',
#  'Chaim Miche',
#  'Chev Polson',
#  'Sherwin Marriage',
#  'Babara Konke',
#  'Ethelind Gloster',
#  'Betteann Tsarovic',
#  'Montague Devoy',
#  'Sibelle Godfray',
#  'Flinn Daspar',
#  'Dalis Caves',
#  'Christin Worters',
#  'Gayel Goodluck',
#  'Lilli Skinner',
#  'Norrie Emmanuele',
#  'Stanislaw McClenan',
#  'Leilah St. Leger',
#  'Ingemar Gierok',
#  'Winnah Sprowell',
#  'Kim Boldry',
#  'Katrina Hexam',
#  'Tucky Tiley',
#  'Lanette Trainor',
#  'Marcia Custy',
#  'Obadiah Delahunt',
#  'Denny Avrahamy',
#  'Casey Di Claudio',
#  'Jessie Willimot',
#  'Hanni MacInherney',
#  'Titos Poppy',
#  'Mariann Matyugin',
#  'Kimble Kneebone',
#  'Raynell Tollerfield',
#  'Annie Woolford',
#  'Ryun Shearwood',
#  'Martynne Valerio',
#  'Sherman Vaulkhard',
#  'Regina Pemble',
#  'Aggi Wase',
#  'Yorke Hurran',
#  'Miller Kegley',
#  'Carlos Kerrich',
#  'Lezley Langshaw',
#  'Dewain Goulborn',
#  'Jorgan Kielt',
#  'Robinetta Normabell',
#  'Webster Leppington',
#  'Ruby Farnworth',
#  'Rozele Moncarr',
#  'Lorine Warrillow',
#  'Minta Counihan',
#  'Janel Atkirk',
#  'Adelice Huckerbe',
#  'Wendy Meynell',
#  'Iain Husk',
#  'Antonia Tarbet',
#  'Cooper Cloney',
#  'Lizzy Spittles',
#  'Bryana Champ',
#  'Georgi Bleas',
#  'Fonsie Bonehill',
#  'Phil Tsarovic',
#  'Delores Fenwick',
#  'Clarisse Tilmouth',
#  'Abbott Caustic',
#  'Martyn Basil',
#  'Orly Feirn',
#  'Gabriell Winsborrow',
#  'Noreen Glidder',
#  'Dorelle Thwaites',
#  'Ted Tatersale',
#  'Delinda Kiebes',
#  'Desirae Clemmey',
#  'Carly Suston',
#  'Fleming Colls',
#  'Terrijo Hemeret',
#  'Kane Betser',
#  'Abner Dalligan',
#  'Jolie Brightie',
#  'Hastings Lockett',
#  'Duffie Andreou',
#  'Darryl Bletsor',
#  'Loise Shortt',
#  'Gian Di Biagi',
#  'Dallas Rowantree',
#  'Trevar Monnoyer',
#  'Lorilyn Panner',
#  'Felipa McKaile',
#  'Tiffanie Ravel',
#  'Leroy Moizer',
#  'Addy Bleesing',
#  'Dewie Howton',
#  'Dianne Esposita',
#  'Verney Legging',
#  'Kaitlyn Inge',
#  'Erwin Hobson',
#  'Aarika Eeles',
#  'Aurora Stockdale',
#  'Catherina Toner',
#  'Claiborne Yanyushkin',
#  "Kass O' Concannon",
#  'Carolina Daddow',
#  'Aaron Antonsen',
#  'Paton Cahalin',
#  'Angie Spyby',
#  'Karlan Woolgar',
#  'Walsh Pranger',
#  'Jacqueline Yglesia',
#  'Parnell Kinloch',
#  'Shena Townshend',
#  'Kelli Nunn',
#  'Minda Treves',
#  'Perren Riglar',
#  'Shurlock Rubanenko',
#  'Karlik Anan',
#  'Mayne Wall',
#  'Catherin Winger',
#  'Sioux Smillie',
#  'Tobin Grice',
#  'Hercules Curneen',
#  'Darcie Hubeaux',
#  'Ellyn Zwicker',
#  'Davide Marrow',
#  'Finley Riolfi',
#  'Rosemonde Ilyukhov',
#  'Marten McKall',
#  'Crista Portinari',
#  'Torrence Havoc',
#  'Rici Jocic',
#  "Tad O'Loughnan",
#  'Danyelle Aslet',
#  'Wallas Sabberton',
#  'Genevra Berkery',
#  'Roarke Berthe',
#  'Ryan Searson',
#  'Kerri Polson',
#  'Allister Grigorini',
#  'Terese Thoumasson',
#  'Franklyn Ickovitz',
#  'Byrom Trye',
#  'Hamlin Shearston',
#  'Patrizia Drew-Clifton',
#  'Thane Kindell',
#  'Basile Speerman',
#  'Jamison Line',
#  'Ev Tremathack',
#  'Care Gladdis',
#  'Gerrie Nilles',
#  'Bat Tomczynski',
#  'Bernelle Sheavills',
#  'Alvera Marvelley',
#  'Lothaire Luxford',
#  'Glynn Wakerley',
#  'Parrnell Jeff',
#  'Pat Warstall',
#  'Willyt Vannuccini',
#  'Gaelan Petrashkov',
#  'Stirling Francesc']

# %% [markdown]
# ## Writing to CSV Files
#
# We can also write csv files, either new ones or add on to existing ones.

# %% [markdown]
# ### New File
# **This will also overwrite any exisiting file with the same name, so be careful with this!**

# %%
# newline controls how universal newlines works (it only applies to text
# mode). It can be None, '', '\n', '\r', and '\r\n'. 
file_to_output = open('to_save_file.csv','w',newline='')

# %%
csv_writer = csv.writer(file_to_output,delimiter=',')

# %%
csv_writer.writerow(['a','b','c'])
# Out:
# 7

# %%
csv_writer.writerows([['1','2','3'],['4','5','6']])

# %%
file_to_output.close()

# %% [markdown]
# ____
# ### Existing File

# %%
f = open('to_save_file.csv','a',newline='')

# %%
csv_writer = csv.writer(f)

# %%
csv_writer.writerow(['new','new','new'])
# Out:
# 13

# %%
f.close()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
